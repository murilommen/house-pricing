# %%
import pandas as pd
import pickle

# %%
with open("../data/model.pkl", "rb") as f:
    model = pickle.load(f)

# %%
model.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'n_features_in_': 285,
#  'coef_': array([-5.54397067e-03,  3.41703312e-04,  4.12001262e-02,  4.69662341e-02,
#          4.43083568e-02,  7.13994953e-02,  2.16383488e-02,  3.64459202e-03,
#          2.25242954e-03, -4.36096572e-02, -2.56001545e-02,  5.99160197e-02,
#          1.32820787e-02,  3.24651525e-02, -1.03367088e-03,  1.07930266e-01,
#          9.18178415e-03,  5.14918971e-04,  5.21961722e-03,  8.35004891e-03,
#          7.87658875e-03, -4.06102354e-03,  1.21166880e-03,  1.37552317e-02,
#         -5.60248111e-03,  1.29212779e-02,  2.87102232e-02,  1.06904127e-02,
#          5.15091233e-03,  2.16649652e-03,  6.41150066e-03,  1.06507232e-02,
#          1.54323111e-02, -7.38967492e-04, -1.90074265e-03, -4.61218856e-03,
#         -2.73588143e-01,  1.01770369e-01,  8.16042346e-02,  5.18377308e-02,
#          3.83758087e-02, -6.11433917e-03,  6.11433917e-03, -1.92774728e-02,
# ...
